# %% [markdown]
# <a href="https://colab.research.google.com/github/srinithimohan/EarthBuddy/blob/main/EarthBuddy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\t\tWelcome to EarthBuddy, a friendly bot designed to help you find ways to improve our planet and help you learn!")

# Function eb() (EarthBuddy). Ouputs main menu and calls functions of different choices, as well as diverts errors.
def eb():
    user = input("""\n\nEnter the number of what you would like to do:
      1) Find out if you can recycle an object?
      2) Learn how to reduce your carbon-footprint?
      3) Look at our dictionary and learn some terms about our planet?\t\t\n""")
    if user == "1":
      rr()
    elif user == "2":
      cf()
    elif user == "3":
      dicts()
    elif user.isdigit() and int(user) > 3:
      print("The number you entered is too high. Try again!")
      eb()
    elif user.isdigit() and int(user) < 1:
      print("The number you entered is too low. Try again!")
      eb()
    elif user.isalpha() or user.isalnum():
      print("You must enter a number in the list. Try again!")
      eb()


# Function rr - helps user recycle depending on options
def rr():
  print('\nAll right - let\'s see if we can recycle your object! If you want to quit this program at any time, just enter "quit"')

  # Category while loop
  while True:
    category = input("""Please enter the number that is assigned to the following categories that matches your object:
    1 - Paper/Cardboard
    2 - Plastic
    3 - Glass
    4 - Aluminum
    5 - Food
    \n""")

    if category == "1":
      # Paper/cardboard while loop
      while True:
          pc = input("""\nPlease enter the number that is assigned to the type of paper/cardboard product you want to recycle:
      1 - Newspapers
      2 - Magazines
      3 - Pizza Boxes
      4 - Mail
      5 - Takeout Containers (Paper and Cardboard)
      6 - Cardboard Containers
      7 - Shredded Paper
      8 - Books
      9 - Gift Wrap
      \n""")

          if pc == "1":
              print("\nNewspapers can be recycled!")
              break

          elif pc == "2":
              print("\nMagazines can be recycled!")
              break

          elif pc == "3":
              print("""\nPizza Boxes can be recycled, even if they have grease on them.
  Make sure to remove food scraps and flatten the box before recycling them.""")
              break

          elif pc == "4":
              print("\nMail can be recycled, even with envelopes with plastic windows.")
              break

          elif pc == "5":
              while True:
                food = input("\nIs there food is on the boxes? Yes or No: ")
                if food.lower() == "yes":
                    print('\tTry rinsing or wiping off the residue on the container. If the boxes are contaminated with food, it is not clean enough to recycle.')
                    break

                elif food.lower() == "no":
                    print("\tYou may recycle your containers, as long as it is not contaminated with food.")
                    break

                elif food.lower() == "quit":
                    print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
                    while True:
                      q = input()

                      if q.lower() == "c":
                        print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
                        break

                      if q.lower() == "e":
                        eb()
                        break
                      break
                    break

                else:
                    print('Sorry, this is a "yes" and "no" question. Please enter your response to the question.')

              break

          elif pc == "6":
              print("\nYou sure can recycle cardboard boxes! Just remember to flatten them beforehand.")
              break

          elif pc == "8":
              while True:
                book = input("\nIs the book in good condition? Yes or No: ")
                if book.lower() == "yes":
                    print("\tInstead of recycling your book, try donating it instead! You can donate your book at a school or a local non-profit.")
                    break

                elif book.lower() == "no":
                    print("""\tIf the book is not in usable condition, you may recycle it. Although paperback
            books can be recycled as is, be sure to remove the cover from hardcover books and then recycle them.""")
                    break

                elif book.lower() == "quit":
                    print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
                    while True:
                      q = input()

                      if q.lower() == "c":
                        print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
                        break

                      if q.lower() == "e":
                        eb()
                        break
                      break
                    break

                else:
                    print('Sorry, this is a "yes" and "no" question. Please enter your response to the question.')

                break

          elif pc == "7":
              print("Being able to recycle shredded paper depends on your local recycling program.")
              break

          elif pc == "9":
            while True:
              gw = input("\nDoes your gift wrap have shiny or laminated coating? Yes or No: ")
              if gw.lower() == "yes":
                  print("""\tThe gift wrap is not recyclable. Try using gift wrap that is recyclable or made from recycled materials.
          Newspaper is a great alternative!""")
                  break

              elif gw.lower() == "no":
                print("Yes, you can recycle the gift wrap.")
                break

              elif gw.lower() == "quit":
                    print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
                    while True:
                      q = input()

                      if q.lower() == "c":
                        print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
                        break

                      elif q.lower() == "e":
                        eb()
                        break
                      break
                    break

              else:
                print('Sorry, this is a "yes" and "no" question. Please enter your response to the question.')


          elif pc.isdigit() and int(pc) > 9:
            print("The number you entered is larger than the ones on the list. Try again!")

          elif pc.isdigit() and int(pc) < 1:
            print("The number you entered is smaller than the ones on the list. Try again!")

          elif pc.lower() == "quit":
            print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
            while True:
              q = input()

              if q.lower() == "c":
                print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
                break

              elif q.lower() == "e":
                eb()
                break
            break

          elif pc.isalpha() or pc.isalnum():
            print("You must enter a number that matches the object you want to recycle. Try again!")

          else:
            print("That is an invalid input. Please enter the number that matches the object you want to recycle. Try again! ")
      break

    elif category == "2":
      # Plastic while loop
      while True:
          pc = input("""\nPlease enter the number that is assigned to the type of plastic product you want to recycle:"
        1 - Bags, Wraps, and Films
        2 - Plastic Bottles and Caps
        3 - Styrafoam
        \n""")

          if pc == "1":
              print("""\nThese items are recyclable, but they cannot go into a regular bin.
  Visit the Plastic Film Recycling website or the Earth 911 website to find locations near you that recycle these materials.""")
              break

          elif pc == "2":
              print("\nYes, plastic bottles and caps can by recyclable! Caps and labels can be left on.")
              break

          elif pc == "3":
              print("""\nVery few recycling localities accept styrafoam in curbside pickup.
  Visit the Earth 911 website to learn where you can drop-off styrafoam to be recycled.""")
              break

          elif pc.isdigit() and int(pc) > 3:
            print("The number you entered is larger than the ones on the list. Try again!")

          elif pc.isdigit() and int(pc) < 1:
            print("The number you entered is smaller than the ones on the list. Try again!")

          elif pc.lower() == "quit":
            print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
            while True:
              q = input()

              if q.lower() == "c":
                print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
                break

              elif q.lower() == "e":
                eb()
                break
            break

          elif pc.isalpha() or pc.isalnum():
            print("You must enter a number that matches the object you want to recycle. Try again!")

          else:
            print("That is an invalid input. Please enter the number that matches the object you want to recycle. Try again!")
      break

    elif category == "3":
      # Glass while loop
      while True:
          pc = input("""\nPlease enter the number that is assigned to the type of glass product you want to recycle:"
        1 - Different Glass Colors/Types
        2 - Broken Glass
        3 - Metal Bottle Cap on Glass Bottle
        \n""")

          if pc == "1":
              print("""\nYou can recycle different colors and types of glass.""")
              break

          elif pc == "2":
              print("\nDo not recycle broken glass! The shards can harm workers and damage equipment.")
              break

          elif pc == "3":
              print("""\nMetal caps on glass bottles should be recycled seperately from the bottle.""")
              break

          elif pc.isdigit() and int(pc) > 3:
            print("The number you entered is larger than the ones on the list. Try again!")

          elif pc.isdigit() and int(pc) < 1:
            print("The number you entered is smaller than the ones on the list. Try again!")

          elif pc.lower() == "quit":
            print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
            while True:
              q = input()

              if q.lower() == "c":
                print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.""")
                break

              elif q.lower() == "e":
                eb()
                break
            break

          elif pc.isalpha() or pc.isalnum():
            print("You must enter a number that matches the object you want to recycle. Try again!")

          else:
            print("That is an invalid input. Please enter the number that matches the object you want to recycle. Try again!")
      break

    elif category == "4":
      # Aluminum while loop
      while True:
          pc = input("""\nPlease enter the number that is assigned to the type of aluminum product you want to recycle:
        1 - Aluminum Cans
        2 - Aluminum Foil
        \n""")

          if pc == "1":
            while True:
              al = input("\nIs your aluminum can crushed? Yes or No: ")
              if al.lower() == "yes":
                  print("""\tUsually, aluminum cans should not be crushed before they are recycled, for it
      can be hard to detect. But if you live in an area with multi-stream recycling, it should be no problem.""")
                  break

              elif al.lower() == "no":
                print("Yes, you can recycle the can.")
                break

              elif al.lower() == "quit":
                    print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
                    while True:
                      q = input()

                      if q.lower() == "c":
                        print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
                        break

                      elif q.lower() == "e":
                        eb()
                        break
                      break
                    break

              else:
                print('Sorry, this is a "yes" and "no" question. Please enter your response to the question.')


          elif pc == "2":
              print("\nYes, you can recycle aluminum foil. Just be sure to remove any residue of food.")
              break

          elif pc.isdigit() and int(pc) > 2:
            print("The number you entered is larger than the ones on the list. Try again!")

          elif pc.isdigit() and int(pc) < 1:
            print("The number you entered is smaller than the ones on the list. Try again!")

          elif pc.lower() == "quit":
            print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
            while True:
              q = input()
              if q.lower() == "c":
                print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/. """)
                break

              if q.lower() == "e":
                eb()
                break
              break
            break

          elif pc.isalpha() or pc.isalnum():
            print("You must enter a number that matches the object you want to recycle. Try again!")

          else:
            print("That is an invalid input. Please enter the number that matches the object you want to recycle. Try again!")
      break

    elif category == "5":
      print("""Food cannot be recycled - period. But there are ways to lower food waste, such as:
          - Buying only what you need, and eating leftovers
          - Composting""")
      break

    # Errors in category loop
    elif category.isdigit() and int(category) > 5:
      print("The number you entered is larger than the ones on the list. Try again!")

    elif category.isdigit() and int(category) < 1:
      print("The number you entered is smaller than the ones on the list. Try again!")

    elif category.lower() == "quit":
      print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
      while True:
        q = input()
        if q.lower() == "c":
          print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.""")
          break

        elif q.lower() == "e":
          eb()
          break
        break
      break


    elif category.isalpha() or category.isalnum():
      print("You must enter a number that matches the object you want to recycle. Try again!")

    else:
      print("That is an invalid input. Please enter the number that matches the object you want to recycle. Try again!")


# Function cf - takes user input, outputs suggestions depending on what user inputs
def cf():
  print("""\nYour carbon footprint is the amount of carbon emitted as a result of someones activities.""")
  print('\nLet\'s see how you can reduce your carbon footprint. For all the questions below, please enter "yes" or "no". If you would like to quit at anytime, please enter "quit".')
  yes = 0


  while True:
    one = input("Do you tend to leave the lights on when you leave a room? ")
    if one.lower() == "yes":
      yes += 1
      break

    elif one.lower() == "no":
      pass
      break

    elif one.lower() == "quit":
      print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
      while True:
        q = input()
        if q.lower() == "c":
          print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
          break

        elif q.lower() == "e":
          eb()
          break
      break

    else:
      print('This is a "yes" or "no" question. Please enter your response in the question.')


  while True:
    two = input("Do you use plastic bags when grocery shopping, or for any other reason? ")
    if two.lower() == "yes":
      yes += 1
      break

    elif two.lower() == "no":
      pass
      break

    elif two.lower() == "quit":
      print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
      while True:
        q = input()
        if q.lower() == "c":
          print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
          break

        elif q.lower() == "e":
          eb()
          break
      break

    else:
      print('This is a "yes" or "no" question. Please enter your response in the question.')


  while True:
    three = input("Do you fly on a plane or drive a car often? ")
    if three.lower() == "yes":
      yes += 1
      break

    elif three.lower() == "no":
      pass
      break

    elif three.lower() == "quit":
      print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
      while True:
        q = input()
        if q.lower() == "c":
          print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
          break

        elif q.lower() == "e":
          eb()
          break
        break
      break

    else:
      print('This is a "yes" or "no" question. Please enter your response in the question.')



  while True:
    four = input("Do you leave the water running when you brush your teeth, or take long showers? ")
    if four.lower() == "yes":
      yes += 1
      break

    elif four.lower() == "no":
      pass
      break

    elif four.lower() == "quit":
      print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
      while True:
        q = input()
        if q.lower() == "c":
          print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
          break

        elif q.lower() == "e":
          eb()
          break
      break

    else:
      print('This is a "yes" or "no" question. Please enter your response in the question.')


  while True:
    six = input("Do you throw away recycable items in the trash rather than recycling them? ")
    if six.lower() == "yes":
      yes += 1
      break

    elif six.lower() == "no":
      pass
      break

    elif six.lower() == "quit":
      print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
      while True:
        q = input()
        if q.lower() == "c":
          print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
          break

        elif q.lower() == "e":
          eb()
          break
      break

    else:
      print('This is a "yes" or "no" question. Please enter your response in the question.')


  while True:
    seven = input("Do you buy clothes that are in trend or go shopping often? ")
    if seven.lower() == "yes":
      yes += 1
      break

    elif seven.lower() == "no":
      pass
      break

    elif seven.lower() == "quit":
      print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
      while True:
        q = input()
        if q.lower() == "c":
          print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
          break

        elif q.lower() == "e":
          eb()
          break
      break

    else:
      print('This is a "yes" or "no" question. Please enter your response in the question.')

  print('\n\nYou have chosen "yes" {:d} times'.format(yes))
  print("\nHere are some suggestions for you to reduce your carbon footprint based on your choices:")
  if one.lower() == "yes":
    print("\n\t- Turn off the lights before you leave a room, so you can save energy and reduce carbon emission")
  if two.lower() == "yes":
    print("""\n\t- Instead of using single-use plastic bags, try using recycled paper bags or
        reusable foldable shopping bags. Plastic bags can pollute our land and water""")
  if three.lower() == "yes":
    print("\n\t- Driving cars and using planes release a lot of greenhouse gases. Rather, take public transportation such as trains and buses, or cycle")
  if four.lower() == "yes":
    print("""\n\t- Turn off running water from faucets and don't take showers longer than
        10 minutes. This takes up less water from natural water sources, and saves you money as well""")
  if six.lower() == "yes":
    print("""\n\t- It is very important to recycle because less garbage winds up in our landfills, and
        prevents pollution. It also saves energy and production costs.""")
  if seven.lower() == "yes":
    print("""\n\t- The fashion industry is one of the most polluting industries in the world. It creates a massive amount of
        pollution each year. Rather, buy clothes from thrift or vintage shops, and wear previously owened clothes more often""")

def dicts():
  print("""\n\nWelcome to EarthBuddy Dictionary! Enter the number next to the word you want to learn about. Enter "quit" if you would like to exit.""")
  print("""\t\t1) Recycle\t\t2) Reuse\t\t3) Climate Change\t4) Biodegradable
\t\t5) Carbon Footprint\t6) Carbon Emissions\t7) Compost\t\t8) Eco-concious
\t\t9) Fossil Fuels\t\t10) Greenhouse Effect\t11) Zero Waste\t\t12) Sustainabilty""")
  while True:
    q = input()
    if q == "1":
      print("Recycle - to convert waste materials into new materials and objects.")
      break

    elif q == "2":
      print("Reuse - use again or more than once.")
      break

    elif q == "3":
      print("Climate Change - how Earth's climate demonstrates new weather patterns that last for a few decades.")
      break

    elif q == "4":
      print("Biodegradable - a product or substance that can decompose naturally by bacteria or living organisms.")
      break

    elif q == "5":
      print("Carbon Footprint - the amount of carbon emitted as a result of someones activities.")
      break

    elif q == "6":
      print("Carbon Emmissions - emissions stemming from the burning of fossil fuels and the manufacture of cement")
      break

    elif q == "7":
      print("Compost - organic matter that has decomposed")
      break

    elif q == "8":
      print("Eco-concious - Showing concern for the environment.")
      break

    elif q == "9":
      print("Fossil Fuels - coal, natural gas, oil and petroleum formed over millions of years from organic matter such as plants and other life forms.")
      break

    elif q == "10":
      print("""Greenhouse Effect - the problem caused by increased quantities of gases such as
carbon dioxide in the air. These gases trap the heat from the sun, and cause a gradual rise in the temperature of the Earth’s atmosphere.""")
      break

    elif q == "11":
      print("Zero Waste - A popular new movement where individuals and families try to create no waste which will end up in landfill.")
      break

    elif q == "12":
      print("Sustainability - not depleting natural resources in order to maintain an ecological balance.")
      break

    elif q.isdigit() and int(q) > 12:
      print("That number is too high. Try again!")

    elif q.isdigit() and int(q) < 1:
      print("That number is too low. Try again!")

    elif q.lower() == "quit":
      print('\n\nYou have decided to quit this program. If you would you like to explore EarthBuddy more, type "E". If you would like to see the credits, type "C". ')
      while True:
        q = input()
        if q.lower() == "c":
          print("""\nThank you for using EarthBuddy! Resources:
\t - EPA, Environmental Protection Agency, https://www.epa.gov/recycle/how-do-i-recycle-common-recyclables.
\t - “Eco-Friendly Terminology - a Comprehensive Glossary of Green Words.”
\t   Green Eco Friend, 21 Sept. 2021, https://greenecofriend.co.uk/eco-friendly-terminology/.  """)
          break

        elif q.lower() == "e":
          eb()
          break
      break

    elif q.isalpha() or q.isalnum():
      print("You must enter a number on the list. Try again!")

    else:
      print("You have entered a invalid input. Try again!")



eb()
# Out:
# 		Welcome to EarthBuddy, a friendly bot designed to help you find ways to improve our planet and help you learn!
